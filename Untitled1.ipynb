# %% [markdown]
# # Libraries

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Dataset

# %%
data = yf.download('BTC-USD','2021-01-01','2024-11-30')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# # Data in Tabular Form (Panda)

# %%
data = pd.DataFrame(data)

# %%
data
# Out:
# Price                         Adj Close         Close          High  \
# Ticker                          BTC-USD       BTC-USD       BTC-USD
# Date
# 2021-01-01 00:00:00+00:00  29374.152344  29374.152344  29600.626953
# 2021-01-02 00:00:00+00:00  32127.267578  32127.267578  33155.117188
# 2021-01-03 00:00:00+00:00  32782.023438  32782.023438  34608.558594
# 2021-01-04 00:00:00+00:00  31971.914062  31971.914062  33440.218750
# 2021-01-05 00:00:00+00:00  33992.429688  33992.429688  34437.589844
# ...                                 ...           ...           ...
# 2024-11-25 00:00:00+00:00  93102.296875  93102.296875  98935.031250
# 2024-11-26 00:00:00+00:00  91985.320312  91985.320312  94991.750000
# 2024-11-27 00:00:00+00:00  95962.531250  95962.531250  97361.179688
# 2024-11-28 00:00:00+00:00  95652.468750  95652.468750  96650.203125
# 2024-11-29 00:00:00+00:00  97461.523438  97461.523438  98693.171875
#
# Price                               Low          Open       Volume
# Ticker                          BTC-USD       BTC-USD      BTC-USD
# Date
# 2021-01-01 00:00:00+00:00  28803.585938  28994.009766  40730301359
# 2021-01-02 00:00:00+00:00  29091.181641  29376.455078  67865420765
# 2021-01-03 00:00:00+00:00  32052.316406  32129.408203  78665235202
# 2021-01-04 00:00:00+00:00  28722.755859  32810.949219  81163475344
# 2021-01-05 00:00:00+00:00  30221.187500  31977.041016  67547324782
# ...                                 ...           ...          ...
# 2024-11-25 00:00:00+00:00  92642.914062  98033.445312  80909462490
# 2024-11-26 00:00:00+00:00  90770.812500  93087.281250  91656519855
# 2024-11-27 00:00:00+00:00  91778.664062  91978.140625  71133452438
# 2024-11-28 00:00:00+00:00  94677.351562  95954.945312  52260008261
# 2024-11-29 00:00:00+00:00  95407.882812  95653.953125  54968682476
#
# [1429 rows x 6 columns]

# %%
data.shape
# Out:
# The kernel failed to start as the Python Environment 'Python 3.13.0' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.

# %%
data.reset_index(inplace=True)

# %%
data
# Out:
# Price                       Date     Adj Close         Close          High  \
# Ticker                                 BTC-USD       BTC-USD       BTC-USD
# 0      2021-01-01 00:00:00+00:00  29374.152344  29374.152344  29600.626953
# 1      2021-01-02 00:00:00+00:00  32127.267578  32127.267578  33155.117188
# 2      2021-01-03 00:00:00+00:00  32782.023438  32782.023438  34608.558594
# 3      2021-01-04 00:00:00+00:00  31971.914062  31971.914062  33440.218750
# 4      2021-01-05 00:00:00+00:00  33992.429688  33992.429688  34437.589844
# ...                          ...           ...           ...           ...
# 1424   2024-11-25 00:00:00+00:00  93102.296875  93102.296875  98935.031250
# 1425   2024-11-26 00:00:00+00:00  91985.320312  91985.320312  94991.750000
# 1426   2024-11-27 00:00:00+00:00  95962.531250  95962.531250  97361.179688
# 1427   2024-11-28 00:00:00+00:00  95652.468750  95652.468750  96650.203125
# 1428   2024-11-29 00:00:00+00:00  97461.523438  97461.523438  98693.171875
#
# Price            Low          Open       Volume
# Ticker       BTC-USD       BTC-USD      BTC-USD
# 0       28803.585938  28994.009766  40730301359
# 1       29091.181641  29376.455078  67865420765
# 2       32052.316406  32129.408203  78665235202
# 3       28722.755859  32810.949219  81163475344
# 4       30221.187500  31977.041016  67547324782
# ...              ...           ...          ...
# 1424    92642.914062  98033.445312  80909462490
# 1425    90770.812500  93087.281250  91656519855
# 1426    91778.664062  91978.140625  71133452438
# 1427    94677.351562  95954.945312  52260008261
# 1428    95407.882812  95653.953125  54968682476
#
# [1429 rows x 7 columns]

# %% [markdown]
# # Removing not nedeed columns

# %%
data.drop(columns = ['Adj Close','Date','Open','High','Low','Volume'],inplace=True)

# %%
data
# Out:
# Price          Close
# Ticker       BTC-USD
# 0       29374.152344
# 1       32127.267578
# 2       32782.023438
# 3       31971.914062
# 4       33992.429688
# ...              ...
# 1424    93102.296875
# 1425    91985.320312
# 1426    95962.531250
# 1427    95652.468750
# 1428    97461.523438
#
# [1429 rows x 1 columns]

# %% [markdown]
# # EDA (Explanatory Data Analysis)

# %%
plt.figure(figsize=(8,10))
plt.plot(data)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Training of Data

# %%
train_data = data[:-100]
test_data = data[-100:]

# %%
train_data.shape
# Out:
# (1329, 1)

# %%
test_data.shape
# Out:
# (100, 1)

# %% [markdown]
# # Libraries

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))

# %%
train_data_scale = scaler.fit_transform(train_data)

# %% [markdown]
# # Limited days (100)

# %%
base_days = 100

# %% [markdown]
# # Base_days Mapping

# %%
x = []
y = []
for i in range(base_days, train_data_scale.shape[0]):
    x.append(train_data_scale[i-base_days:i])
    y.append(train_data_scale[i,0])

# %%
x, y = np.array(x), np.array(y)

# %%
x = np.reshape(x, (x.shape[0],x.shape[1],1))

# %% [markdown]
# # Libraries

# %%
from keras.layers import LSTM, Dense, Dropout
from keras.models import Sequential

# %% [markdown]
# # Model

# %%
model = Sequential()
model.add(LSTM(50, activation = 'relu', return_sequences=True, input_shape=(x.shape[1],1)))
model.add(Dropout(0.2))
model.add(LSTM(60, activation='relu',return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(80, activation='relu',return_sequences=True))
model.add(Dropout(0.4))
model.add(LSTM(120, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(units=1))

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 100, 50)             │          10,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 100, 50)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 100, 60)             │          26,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 100, 60)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_2 (LSTM)                        │ (None, 100, 80)             │          45,120 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 100, 80)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_3 (LSTM)                        │ (None, 120)                 │          96,480 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 120)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │             121 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 178,761 (698.29 KB)
#  Trainable params: 178,761 (698.29 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam', loss = 'mean_squared_error')

# %%
model.fit(x, y, epochs = 50, verbose =1 )
# Out:
# Epoch 1/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 18s 304ms/step - loss: 0.1204
# Epoch 2/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 296ms/step - loss: 0.0174
# Epoch 3/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 21s 308ms/step - loss: 0.0109
# Epoch 4/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 306ms/step - loss: 0.0120
# Epoch 5/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 21s 307ms/step - loss: 0.0100
# Epoch 6/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 308ms/step - loss: 0.0136
# Epoch 7/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 21s 308ms/step - loss: 0.0090
# Epoch 8/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 307ms/step - loss: 0.0102
# Epoch 9/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 307ms/step - loss: 0.0111
# Epoch 10/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 21s 308ms/step - loss: 0.0092
# Epoch 11/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 306ms/step - loss: 0.0087
# Epoch 12/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 12s 308ms/step - loss: 0.0114
# Epoch 13/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 12s 308ms/step - loss: 0.0085
# Epoch 14/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 12s 308ms/step - loss: 0.0075
# Epoch 15/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 302ms/step - loss: 0.0077
# Epoch 16/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 301ms/step - loss: 0.0082
# Epoch 17/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 21s 303ms/step - loss: 0.0064
# Epoch 18/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 304ms/step - loss: 0.0086
# Epoch 19/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 11s 284ms/step - loss: 0.0069
# Epoch 20/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 21s 305ms/step - loss: 0.0061
# Epoch 21/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 21s 308ms/step - loss: 0.0070
# Epoch 22/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 306ms/step - loss: 0.0071
# Epoch 23/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 12s 305ms/step - loss: 0.0056
# Epoch 24/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 19s 264ms/step - loss: 0.0057
# Epoch 25/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 22s 301ms/step - loss: 0.0062
# Epoch 26/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 22s 351ms/step - loss: 0.0055
# Epoch 27/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 18s 296ms/step - loss: 0.0063
# Epoch 28/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 21s 307ms/step - loss: 0.0068
# Epoch 29/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 307ms/step - loss: 0.0055
# Epoch 30/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 305ms/step - loss: 0.0057
# Epoch 31/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 11s 276ms/step - loss: 0.0055
# Epoch 32/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 22s 307ms/step - loss: 0.0052
# Epoch 33/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 307ms/step - loss: 0.0056
# Epoch 34/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 302ms/step - loss: 0.0053
# Epoch 35/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 21s 310ms/step - loss: 0.0049
# Epoch 36/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 304ms/step - loss: 0.0046
# Epoch 37/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 22s 354ms/step - loss: 0.0050
# Epoch 38/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 12s 300ms/step - loss: 0.0054
# Epoch 39/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 21s 306ms/step - loss: 0.0062
# Epoch 40/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 21s 309ms/step - loss: 0.0049
# Epoch 41/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 306ms/step - loss: 0.0055
# Epoch 42/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 304ms/step - loss: 0.0049
# Epoch 43/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 21s 305ms/step - loss: 0.0043
# Epoch 44/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 305ms/step - loss: 0.0048
# Epoch 45/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 11s 284ms/step - loss: 0.0046
# Epoch 46/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 11s 272ms/step - loss: 0.0048
# Epoch 47/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 22s 305ms/step - loss: 0.0046
# Epoch 48/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 19s 274ms/step - loss: 0.0046
# Epoch 49/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 22s 321ms/step - loss: 0.0039
# Epoch 50/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 19s 298ms/step - loss: 0.0042

# %% [markdown]
# # Testing of Data

# %%
test_data = pd.concat((train_data.tail(100), test_data), ignore_index=True)

# %%
test_data
# Out:
# Price          Close
# Ticker       BTC-USD
# 0       61552.789062
# 1       66267.492188
# 2       65231.582031
# 3       67051.875000
# 4       66940.804688
# ..               ...
# 195     93102.296875
# 196     91985.320312
# 197     95962.531250
# 198     95652.468750
# 199     97461.523438
#
# [200 rows x 1 columns]

# %%
test_data_scale = scaler.transform(test_data)

# %% [markdown]
# # Mapping

# %%
x = []
y = []

for i in range(base_days, test_data_scale.shape[0]):
    x.append(test_data_scale[i-base_days:i])
    y.append(test_data_scale[i,0])

# %%
x, y = np.array(x), np.array(y)

# %%
x = np.reshape(x, (x.shape[0],x.shape[1],1))

# %% [markdown]
# # Prediction

# %%
pred = model.predict(x)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 232ms/step

# %%
pred = scaler.inverse_transform(pred)

# %%
pred
# Out:
# array([[59902.617],
#        [60476.145],
#        [61088.816],
#        [61784.688],
#        [62509.93 ],
#        [63023.79 ],
#        [62799.51 ],
#        [61732.312],
#        [60340.258],
#        [59203.887],
#        [58634.848],
#        [58501.707],
#        [58739.98 ],
#        [59074.27 ],
#        [59282.848],
#        [59049.793],
#        [58110.402],
#        [56715.547],
#        [55463.93 ],
#        [54900.195],
#        [55063.723],
#        [55796.016],
#        [56862.38 ],
#        [58127.086],
#        [59325.793],
#        [60126.977],
#        [60205.67 ],
#        [59860.965],
#        [59618.586],
#        [59800.277],
#        [60469.85 ],
#        [61477.336],
#        [62523.37 ],
#        [63264.414],
#        [63564.24 ],
#        [63382.383],
#        [63139.297],
#        [63156.707],
#        [63525.664],
#        [64132.598],
#        [64555.84 ],
#        [64194.43 ],
#        [62980.375],
#        [61474.105],
#        [60439.684],
#        [60137.87 ],
#        [60516.258],
#        [61312.016],
#        [62166.383],
#        [62595.453],
#        [62315.37 ],
#        [61717.19 ],
#        [61313.777],
#        [61294.344],
#        [61829.31 ],
#        [62882.31 ],
#        [64249.184],
#        [65546.39 ],
#        [66498.33 ],
#        [66936.53 ],
#        [66968.76 ],
#        [66669.664],
#        [66264.69 ],
#        [65882.15 ],
#        [65779.836],
#        [65876.125],
#        [66064.25 ],
#        [66297.336],
#        [66667.805],
#        [67371.74 ],
#        [68318.68 ],
#        [69047.41 ],
#        [69106.65 ],
#        [68512.555],
#        [67607.77 ],
#        [66750.195],
#        [66391.51 ],
#        [66922.54 ],
#        [68279.03 ],
#        [70111.36 ],
#        [71935.47 ],
#        [73573.59 ],
#        [75484.95 ],
#        [77510.305],
#        [79444.68 ],
#        [80491.5  ],
#        [80866.3  ],
#        [80885.164],
#        [80828.31 ],
#        [80973.086],
#        [81548.12 ],
#        [82598.125],
#        [84169.86 ],
#        [85770.445],
#        [86564.84 ],
#        [86237.22 ],
#        [84622.88 ],
#        [82624.016],
#        [81847.88 ],
#        [82496.78 ]], dtype=float32)

# %%
m = y
z= []
future_days = 30
for i in range(base_days, len(m)+future_days):
    m = m.reshape(-1,1)
    inter = [m[-base_days:,0]]
    inter = np.array(inter)
    inter = np.reshape(inter, (inter.shape[0], inter.shape[1],1))
    pred = model.predict(inter)
    m = np.append(m ,pred)
    z = np.append(z, pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step

# %%
z = np.array(z)
z = scaler.inverse_transform(z.reshape(-1,1))

# %%
z
# Out:
# array([[84106.6691479 ],
#        [84278.86635834],
#        [82271.51311691],
#        [78832.35007701],
#        [75317.0913201 ],
#        [72649.13081204],
#        [71084.79384391],
#        [70505.02931191],
#        [70460.9605958 ],
#        [70577.28643337],
#        [70551.45446122],
#        [70222.06608022],
#        [69626.10704638],
#        [68907.04657572],
#        [68222.3422182 ],
#        [67679.07849507],
#        [67308.3466642 ],
#        [67075.44910038],
#        [66912.02874986],
#        [66751.25853292],
#        [66551.45348763],
#        [66302.51851752],
#        [66019.20011329],
#        [65727.48051241],
#        [65451.47729649],
#        [65205.35638575],
#        [64991.68595085],
#        [64804.36658644],
#        [64633.82229437],
#        [64471.74067112]])

# %% [markdown]
# # Saving

# %%
model.save('Bitcoin_Price_prediction_Model.keras')
